# %% [markdown]
# ## Naive Bayes
#
# In this assignment, we would be working with SMS data that contains SPAM or HAM messages. When we take a look at our gmail account, we find that a few emails are classified as spam. Similarly, some text messages that are received on the phone are also classified as spam based on a set of characteristics such as wording and so on.
#
# Therefore, we are going to address this problem of detecting SPAM or HAM messages with the help of Naive Bayes algorithm.
#
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading the data
#
# When reading the data, ensure that the '.csv' file is in the same location where your jupyter notebook is used. This way the files are organized and easy to read using the pandas library.

# %%
## Reading the data and removing columns that are not important. 
df = pd.read_csv('C:/Users/SIRISHA/Documents/NLP/spam.csv', sep = ',', encoding = 'latin-1', usecols = lambda col: col not in ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3332/585212140.py in <module>
#       1 ## Reading the data and removing columns that are not important.
# ----> 2 df = pd.read_csv('C:/Users/SIRISHA/Documents/NLP/spam.csv', sep = ',', encoding = 'latin-1', usecols = lambda col: col not in ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/SIRISHA/Documents/NLP/spam.csv'

# %%
df.head() # print head of data frame with help of head function
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Renaming the columns so that we understand the columns easily.

## Rename v1 as "spam_or_ham" and v2 as "message"

df = df.rename(columns = {'v1': 'spam_or_ham', 'v2': 'message'})

# %%
df.head()  # print head of data frame with help of head function
# Out:
#   spam_or_ham                                            message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.describe()
# Out:
#        spam_or_ham                 message
# count         5572                    5572
# unique           2                    5169
# top            ham  Sorry, I'll call later
# freq          4825                      30

# %%
df.groupby('spam_or_ham').describe().T
# Out:
# spam_or_ham                        ham  \
# message count                     4825
#         unique                    4516
#         top     Sorry, I'll call later
#         freq                        30
#
# spam_or_ham                                                  spam
# message count                                                 747
#         unique                                                653
#         top     Please call our customer service representativ...
#         freq                                                    4

# %% [markdown]
# ## Count plot of the output categories: spam or ham
#
# Feel free to take a look at the output and whether the classes are balanced or imbalanced.

# %%
plt.figure(figsize = (10,10))
sns.countplot(x="spam_or_ham", data=df)
plt.title("Spam Vs. Ham Messages count", fontsize = 15)
plt.show()

# %% [markdown]
# ## Upsampling the minority class
#
# It is known that Naive bayes is not robust to class imbalance. It could be seen above that the data is quite imbalanced. Therefore, class balancing must be done before giving it to the Naive Bayes model for prediction.
#
# Feel free to use 'resample' library from sklearn.

# %%
## hint: use resample from sklearn.utils
from sklearn.utils import resample

df_majority = df[df.spam_or_ham =='ham']
df_minority = df[df.spam_or_ham =='spam']

spam_upsample = resample(df_minority, replace = True, 
                        n_samples = df_majority.shape[0],
                        random_state = 101)

df_upsampled = pd.concat([df_majority, spam_upsample])  # concat two data frames i,e majority class data set and upsampled minority class data set
df_upsampled = df_upsampled.sample(frac = 1)

# %%
## Just to ensure that upsampling was done successfully, take a look at the shape of the data in 
## this cell. 

# print the shape of data set with the help of shape function having "spam" as class label
# df_spam=df_upsampled[df_upsampled.spam_or_ham=='spam']

print((df_upsampled[df_upsampled.spam_or_ham=='spam']).shape)
# Out:
# (4825, 2)

# %%
## Ensure that the same number of data points are present for both 'spam' and 'ham' data

# print the shape of data set with the help of shape function having "ham" as class label
print((df_upsampled[df_upsampled.spam_or_ham=='ham']).shape)
# Out:
# (4825, 2)

# %%
print((df_upsampled[df_upsampled.spam_or_ham=='ham']))
# Out:
#      spam_or_ham                                            message
# 5224         ham  \OH FUCK. JUSWOKE UP IN A BED ON A BOATIN THE ...
# 1580         ham  I shall book chez jules for half eight, if tha...
# 1805         ham    God bless.get good sleep my dear...i will pray!
# 3726         ham      Aldrine, rakhesh ex RTM here.pls call.urgent.
# 2128         ham                     Well I'm going to be an aunty!
# ...          ...                                                ...
# 344          ham  My sister cleared two round in birla soft yest...
# 1007         ham  I don't quite know what to do. I still can't g...
# 5565         ham                                       Huh y lei...
# 1483         ham  Purity of friendship between two is not about ...
# 5139         ham  Oh shut it. Omg yesterday I had a dream that I...
#
# [4825 rows x 2 columns]

# %%
## In this cell, we are going to be dividing the data into train and test points
## Ensure that you store the upsampled data in a variable called 'df_upsampled' 
## so that the below operations are performed successfully


## Considering 3000 spam and 3000 ham data points
spam_data_points_train = df_upsampled[df_upsampled.spam_or_ham=='spam'].iloc[:3000]
ham_data_points_train = df_upsampled[df_upsampled.spam_or_ham=='ham'].iloc[:3000]
#spam_data_points_train['message'].shape
#ham_data_points_train['message'].tail()

## Considering the remaining data points for test
spam_data_points_test = df_upsampled[df_upsampled.spam_or_ham=='spam'].iloc[3000:]
ham_data_points_test = df_upsampled[df_upsampled.spam_or_ham=='ham'].iloc[3000:]
#spam_data_points_train.shape

## Concatenate the training ham and spam messages
X_train = pd.concat([spam_data_points_train['message'], ham_data_points_train['message']])
## Concatenating the training ham and spam outputs
y_train = pd.concat([spam_data_points_train['spam_or_ham'], ham_data_points_train['spam_or_ham']])
#X_train
#y_train

## Concatenating the test ham and spam messages
X_test = pd.concat([spam_data_points_test['message'], ham_data_points_test['message']])
## Concatenating the test ham and spam outputs
y_test = pd.concat([spam_data_points_test['spam_or_ham'], ham_data_points_test['spam_or_ham']])
#X_test
#y_test

# %%
## Take a look at the total number of classes and their count using '.value_counts()' for y_train and y_test.
## Ensure that there are equal number of spam and ham messages. 
y_train.value_counts()
# Out:
# spam    3000
# ham     3000
# Name: spam_or_ham, dtype: int64

# %%
y_test.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3332/3494164356.py in <module>
# ----> 1 y_test.value_counts()
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ### Expected Output :
# spam    1825<br>
# ham     1825<br>
# Name: spam_or_ham, dtype: int64

# %% [markdown]
# ## Pre-process the messages
#
# We know that a message contains links, punctuation, stopwords and many other words that don't give a lot of meaning for the Naive Bayes model for prediction.
#
# In the cell below, one must implement text-preprocessing and remove links, punctuations and stopwords. It is also important to lowercase the letters so that 'Admire' and 'admire' are not treated as different words.
#
# In addition to this, perform stemming operation so that similar words are reduced. To know more about stemming, feel free to take a look at this link.
#
# https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html

# %%
# TASK CELL

import nltk
from nltk.corpus import stopwords
ps=PorterStemmer()
def clean_message(message):
    message = message.lower()
    message1 = re.sub(r'^https?:\/\/.*[\r\n]*', '', message) # removing links
    message2 = re.sub(r'[^\w\s]','',message1) #removing punctuations
            
#? Causes the resulting RE to match 0 or 1 repetitions of the preceding RE. https? will match either ‘http’ or ‘https’.
# https?:\/\/ will match any "http://" and "https://" in string
# \S Returns a match where the string DOES NOT contain a white space character
# * Zero or more occurrences
           
            #message3 = re.sub(r"<br>", " ", message1)
            #message4 = re.sub(r"([-?.!,/\"])", r" \1 ", message3)
            #message5 = re.sub(r"[-()\"#/@;%:<>{}`+=~|.!?,']", "", message4)
            #message6 = re.sub(r"[ ]+", " ", message5)
            #message7 = message6.rstrip().strip()
            
    Words= word_tokenize(message2)
    messages=[word for word in Words if word not in stopwords.words('english')]
    messages_cleaned = [ps.stem(word) for word in messages]
    return messages_cleaned

# %%
#Testing the clean_message function
custom =X_train.iloc[0]
print(clean_message(custom))
# Out:
# ['panason', 'bluetoothhdset', 'free', 'nokia', 'free', 'motorola', 'free', 'doublemin', 'doubletxt', 'orang', 'contract', 'call', 'mobileupd8', '08000839402', 'call', '2optout']

# %% [markdown]
# ## Implement a find_occurrence function
#
# In this function, we find the total occurrence of a word giving information such as label, word and frequency dictionary.
#
# Note that this function is used later in the code when we are going to be predicting the output using Naive Bayes.

# %%
# TASK CELL
def find_occurrence(frequency, word, label):
    '''
    Params:
        frequency: a dictionary with the frequency of each pair (or tuple)
        word: the word to look up
        label: the label corresponding to the word
    Return:
        n: the number of times the word with its corresponding label appears.
    '''
    
    n=0
    if (word,label) in frequency:
        n = frequency[(word,label)]
    

    return n

# %% [markdown]
# ## Converting output to numerical format:
#
# We have outputs as 'ham' or 'spam'. In the cell below, we convert it to a numerical format.

# %%
## With the use of mapping function, we replace
## the label in the form of string to an integer. 

output_map = {'ham': 0, 'spam': 1}
y_train = y_train.map(output_map)
y_test = y_test.map(output_map)

# %%
## Ensuring that there are equal number of classes on the training data. 
y_train.value_counts()
# Out:
# 1    3000
# 0    3000
# Name: spam_or_ham, dtype: int64

# %%
## Choosing a random message and taking a look at it.
X_train.iloc[0]
# Out:
# 'Panasonic & BluetoothHdset FREE. Nokia FREE. Motorola FREE & DoubleMins & DoubleTxt on Orange contract. Call MobileUpd8 on 08000839402 or call 2optout'

# %% [markdown]
# From the above cell output, it could be seen that there are a lot of words that don't add a lot of meaning to the text.
#
# Therefore, those words would be removed. It also reduces the computation time.
#
# Therefore, it is a good practice we are following.

# %%
custom_message = X_train.iloc[0]

# print cleaned message
print(clean_message(custom_message))
# Out:
# ['panason', 'bluetoothhdset', 'free', 'nokia', 'free', 'motorola', 'free', 'doublemin', 'doubletxt', 'orang', 'contract', 'call', 'mobileupd8', '08000839402', 'call', '2optout']

# %% [markdown]
# We now use this function to pre-process the message and remove words that don't add a lot of meaning in our model.

# %% [markdown]
# ## Implementing message counter function
#
# It is now time to implement the count function for the messages.
#
# In this function, we count the occurrence of words and get the probabilities
# for the words based on the training data.
#
# In other words, we get the probability of occurrence of a word, given that the output is 'spam'.
#
# Similarly, we also compute the probability of occurence of a word, given that the output is 'ham'.

# %%
# TASK CELL
def message_counter(output_occurrence, messages, spam_or_ham):
    '''
    Params:
        output_occurrence: a dictionary that will be used to map each pair to its frequency
        messages: a list of messages
        spam_or_ham: a list corresponding to the sentiment of each message (either 0 or 1)
    Return:
        output: a dictionary mapping each pair to its frequency
    '''
    ## Steps :
    # define the key, which is the word and label tuple
    # if the key exists in the dictionary, increment the count
    # else, if the key is new, add it to the dictionary and set the count to 1
    
    for label, message in zip(spam_or_ham, messages):
        for word in clean_message(message):
            if (word, label) in list(output_occurrence.keys()):
                output_occurrence[(word, label)] += 1
            else:
                output_occurrence[(word, label)] = 1

    return output_occurrence

# %% [markdown]
# ## Test your function with example messages:
#
# Feel free to run the cell below and understand whether the above function that you have defined is producing the optimum results.

# %%
# Testing your function

result = {}
messages = ['get offer upto 20%', 'I am coming now', 'Click on the link', 'get a latest car', 'canvas class scheduled']
ys = [1, 0, 1, 1, 0]
message_counter(result,messages, ys)
# Out:
# {('get', 1): 2,
#  ('offer', 1): 1,
#  ('upto', 1): 1,
#  ('20', 1): 1,
#  ('come', 0): 1,
#  ('click', 1): 1,
#  ('link', 1): 1,
#  ('latest', 1): 1,
#  ('car', 1): 1,
#  ('canva', 0): 1,
#  ('class', 0): 1,
#  ('schedul', 0): 1}

# %% [markdown]
# ### Expected Output:
# {('get', 1): 2, <br>
#  ('offer', 1): 1, <br>
#  ('upto', 1): 1, <br>
#  ('20', 1): 1, <br>
#  ('i', 0): 1, <br>
#  ('come', 0): 1, <br>
#  ('click', 1): 1, <br>
#  ('link', 1): 1, <br>
#  ('latest', 1): 1, <br>
#  ('car', 1): 1, <br>
#  ('canva', 0): 1, <br>
#  ('class', 0): 1, <br>
#  ('schedul', 0): 1}

# %%
# Build the freqs dictionary for later uses

freqs = message_counter({}, X_train, y_train)

# %%
## Run this cell to get an idea about the corpus of words and their occurrence along with labels. 
## In this, we are computing the frequency of occurrence of word given that a message is 'spam'.
## Similarly, we also compute the frequence of occurence of word given that a message is 'ham'.
freqs
# Out:
# {('panason', 1): 5,
#  ('bluetoothhdset', 1): 5,
#  ('free', 1): 910,
#  ('nokia', 1): 310,
#  ('motorola', 1): 43,
#  ('doublemin', 1): 5,
#  ('doubletxt', 1): 5,
#  ('orang', 1): 121,
#  ('contract', 1): 18,
#  ('call', 1): 1466,
#  ('mobileupd8', 1): 69,
#  ('08000839402', 1): 68,
#  ('2optout', 1): 14,
#  ('special', 1): 79,
#  ('select', 1): 130,
#  ('receiv', 1): 173,
#  ('2000', 1): 14,
#  ('pound', 1): 94,
#  ('award', 1): 280,
#  ('08712402050', 1): 12,
#  ('line', 1): 131,
#  ('close', 1): 22,
#  ('cost', 1): 105,
#  ('10ppm', 1): 12,
#  ('16', 1): 224,
#  ('tc', 1): 188,
#  ('appli', 1): 122,
#  ('ag', 1): 12,
#  ('promo', 1): 12,
#  ('doubl', 1): 79,
#  ('min', 1): 198,
#  ('txt', 1): 636,
#  ('12', 1): 40,
#  ('price', 1): 63,
#  ('linerent', 1): 21,
#  ('latest', 1): 166,
#  ('bluetooth', 1): 39,
#  ('mobil', 1): 566,
#  ('offer', 1): 179,
#  ('call2optoutlf56', 1): 11,
#  ('decemb', 1): 18,
#  ('11mth', 1): 38,
#  ('entitl', 1): 27,
#  ('updat', 1): 83,
#  ('colour', 1): 83,
#  ('camera', 1): 124,
#  ('co', 1): 21,
#  ('08002986906', 1): 13,
#  ('ur', 1): 605,
#  ('cashbal', 1): 31,
#  ('current', 1): 52,
#  ('500', 1): 113,
#  ('maxim', 1): 31,
#  ('cashin', 1): 31,
#  ('send', 1): 283,
#  ('go', 1): 146,
#  ('86688', 1): 81,
#  ('150pmsg', 1): 63,
#  ('cc', 1): 31,
#  ('08718720201', 1): 27,
#  ('po', 1): 108,
#  ('box', 1): 110,
#  ('11414', 1): 15,
#  ('tcrw1', 1): 15,
#  ('rgent', 1): 4,
#  ('2nd', 1): 100,
#  ('attempt', 1): 109,
#  ('contact', 1): 236,
#  ('uu', 1): 11,
#  ('å1250', 1): 9,
#  ('09071512433', 1): 9,
#  ('b4', 1): 32,
#  ('050703', 1): 9,
#  ('tcsbcm4235wc1n3xx', 1): 9,
#  ('callcost', 1): 9,
#  ('150ppm', 1): 134,
#  ('mobilesvari', 1): 9,
#  ('maxå7', 1): 11,
#  ('50', 1): 18,
#  ('thank', 1): 74,
#  ('rington', 1): 136,
#  ('order', 1): 61,
#  ('refer', 1): 18,
#  ('number', 1): 151,
#  ('x49your', 1): 8,
#  ('charg', 1): 109,
#  ('450', 1): 15,
#  ('tone', 1): 323,
#  ('arriv', 1): 31,
#  ('pleas', 1): 219,
#  ('custom', 1): 229,
#  ('servic', 1): 271,
#  ('09065989182', 1): 11,
#  ('announc', 1): 20,
#  ('recent', 1): 26,
#  ('tri', 1): 146,
#  ('make', 1): 52,
#  ('deliveri', 1): 75,
#  ('unabl', 1): 9,
#  ('07090298926', 1): 3,
#  ('reschedul', 1): 9,
#  ('ref9307622', 1): 3,
#  ('chanc', 1): 121,
#  ('realiti', 1): 7,
#  ('fantasi', 1): 34,
#  ('show', 1): 122,
#  ('08707509020', 1): 21,
#  ('20p', 1): 21,
#  ('per', 1): 174,
#  ('ntt', 1): 30,
#  ('ltd', 1): 56,
#  ('1327', 1): 21,
#  ('croydon', 1): 21,
#  ('cr9', 1): 21,
#  ('5wb', 1): 21,
#  ('0870', 1): 16,
#  ('nation', 1): 37,
#  ('rate', 1): 112,
#  ('httptm', 1): 9,
#  ('widelivecomindex', 1): 9,
#  ('wmlid820554ad0a1705572711firsttrueåác', 1): 3,
#  ('c', 1): 78,
#  ('ringtoneåá', 1): 3,
#  ('hi', 1): 44,
#  ('mandi', 1): 7,
#  ('sullivan', 1): 7,
#  ('hotmix', 1): 7,
#  ('fmyou', 1): 7,
#  ('chosen', 1): 21,
#  ('å500000', 1): 7,
#  ('easter', 1): 7,
#  ('prize', 1): 405,
#  ('drawpleas', 1): 7,
#  ('telephon', 1): 7,
#  ('09041940223', 1): 7,
#  ('claim', 1): 445,
#  ('290305', 1): 7,
#  ('transfer', 1): 7,
#  ('someon', 1): 39,
#  ('els', 1): 7,
#  ('week', 1): 280,
#  ('tripl', 1): 7,
#  ('echo', 1): 7,
#  ('shortli', 1): 12,
#  ('enjoy', 1): 49,
#  ('1000', 1): 39,
#  ('flirt', 1): 27,
#  ('girl', 1): 44,
#  ('bloke', 1): 4,
#  ('name', 1): 52,
#  ('age', 1): 34,
#  ('eg', 1): 40,
#  ('zoe', 1): 4,
#  ('18', 1): 163,
#  ('8007', 1): 88,
#  ('join', 1): 75,
#  ('get', 1): 362,
#  ('chat', 1): 170,
#  ('repli', 1): 458,
#  ('video', 1): 127,
#  ('handset', 1): 32,
#  ('750', 1): 79,
#  ('anytim', 1): 60,
#  ('network', 1): 139,
#  ('unlimit', 1): 50,
#  ('text', 1): 570,
#  ('camcord', 1): 67,
#  ('08000930705', 1): 77,
#  ('stay', 1): 8,
#  ('1', 1): 118,
#  ('250', 1): 24,
#  ('top', 1): 54,
#  ('british', 1): 8,
#  ('hotel', 1): 14,
#  ('noth', 1): 21,
#  ('holiday', 1): 114,
#  ('worth', 1): 53,
#  ('å350', 1): 59,
#  ('london', 1): 14,
#  ('02072069400', 1): 2,
#  ('bx', 1): 2,
#  ('526', 1): 2,
#  ('sw73ss', 1): 8,
#  ('hot', 1): 44,
#  ('live', 1): 97,
#  ('0870k', 1): 8,
#  ('å400', 1): 31,
#  ('xma', 1): 82,
#  ('reward', 1): 56,
#  ('wait', 1): 59,
#  ('comput', 1): 22,
#  ('randomli', 1): 11,
#  ('pick', 1): 27,
#  ('loyal', 1): 11,
#  ('09066380611', 1): 11,
#  ('08712402972', 1): 4,
#  ('immedi', 1): 16,
#  ('urgent', 1): 243,
#  ('messag', 1): 170,
#  ('hgsuite3422land', 1): 40,
#  ('roww1j6hl', 1): 23,
#  ('tmobil', 1): 11,
#  ('may', 1): 22,
#  ('phone', 1): 229,
#  ('upgrad', 1): 15,
#  ('pay', 1): 7,
#  ('sim', 1): 19,
#  ('card', 1): 17,
#  ('loyalti', 1): 28,
#  ('0845', 1): 14,
#  ('021', 1): 8,
#  ('3680offer', 1): 4,
#  ('end', 1): 93,
#  ('28thfebtc', 1): 4,
#  ('7250i', 1): 17,
#  ('win', 1): 246,
#  ('auction', 1): 71,
#  ('take', 1): 105,
#  ('part', 1): 57,
#  ('86021', 1): 28,
#  ('roww1jhl', 1): 17,
#  ('guarante', 1): 173,
#  ('40gb', 1): 21,
#  ('ipod', 1): 42,
#  ('mp3', 1): 20,
#  ('player', 1): 44,
#  ('å500', 1): 78,
#  ('word', 1): 87,
#  ('collect', 1): 209,
#  ('83355', 1): 20,
#  ('ibhltd', 1): 14,
#  ('ldnw15h', 1): 14,
#  ('150pmtmsgrcvd18', 1): 14,
#  ('hear', 1): 12,
#  ('new', 1): 263,
#  ('divorc', 1): 6,
#  ('barbi', 1): 6,
#  ('come', 1): 18,
#  ('ken', 1): 6,
#  ('stuff', 1): 6,
#  ('adult', 1): 13,
#  ('content', 1): 50,
#  ('think', 1): 53,
#  ('smart', 1): 5,
#  ('å200', 1): 47,
#  ('weekli', 1): 100,
#  ('quiz', 1): 44,
#  ('play', 1): 84,
#  ('85222', 1): 5,
#  ('nowtc', 1): 5,
#  ('winnersclub', 1): 5,
#  ('84', 1): 5,
#  ('m26', 1): 18,
#  ('3uz', 1): 18,
#  ('gbp150week', 1): 5,
#  ('sorri', 1): 12,
#  ('u', 1): 582,
#  ('unsubscrib', 1): 71,
#  ('yet', 1): 7,
#  ('mob', 1): 121,
#  ('packag', 1): 4,
#  ('term', 1): 48,
#  ('54', 1): 4,
#  ('pl', 1): 49,
#  ('resubmit', 1): 4,
#  ('request', 1): 8,
#  ('expiri', 1): 4,
#  ('themob', 1): 12,
#  ('help', 1): 90,
#  ('4', 1): 481,
#  ('info', 1): 35,
#  ('88066', 1): 16,
#  ('lost', 1): 10,
#  ('3pound', 1): 6,
#  ('freemsg', 1): 40,
#  ('havent', 1): 5,
#  ('im', 1): 37,
#  ('randi', 1): 6,
#  ('sexi', 1): 66,
#  ('femal', 1): 5,
#  ('local', 1): 17,
#  ('luv', 1): 22,
#  ('netcollex', 1): 14,
#  ('08700621170150p', 1): 7,
#  ('msg', 1): 104,
#  ('stop', 1): 443,
#  ('last', 1): 51,
#  ('weekend', 1): 46,
#  ('draw', 1): 158,
#  ('å900', 1): 37,
#  ('09061701851', 1): 5,
#  ('code', 1): 115,
#  ('k61', 1): 5,
#  ('valid', 1): 85,
#  ('12hour', 1): 5,
#  ('1st', 1): 120,
#  ('no1', 1): 49,
#  ('everi', 1): 149,
#  ('8077', 1): 6,
#  ('txting', 1): 57,
#  ('tell', 1): 88,
#  ('mate', 1): 62,
#  ('wwwgetzedcouk', 1): 40,
#  ('pobox', 1): 62,
#  ('36504', 1): 40,
#  ('w45wq', 1): 33,
#  ('norm150pton', 1): 33,
#  ('england', 1): 37,
#  ('v', 1): 15,
#  ('macedonia', 1): 3,
#  ('dont', 1): 81,
#  ('miss', 1): 36,
#  ('goalsteam', 1): 3,
#  ('news', 1): 37,
#  ('team', 1): 13,
#  ('87077', 1): 28,
#  ('trywal', 1): 3,
#  ('scotland', 1): 3,
#  ('4txtì¼120', 1): 3,
#  ('poboxox36504w45wq', 1): 3,
#  ('final', 1): 67,
#  ('å150', 1): 106,
#  ('discount', 1): 41,
#  ('voucher', 1): 157,
#  ('today', 1): 148,
#  ('ye', 1): 58,
#  ('85023', 1): 34,
#  ('savamob', 1): 55,
#  ('member', 1): 34,
#  ('cs', 1): 62,
#  ('pobox84', 1): 30,
#  ('m263uz', 1): 17,
#  ('å300', 1): 34,
#  ('sub', 1): 46,
#  ('entri', 1): 101,
#  ('2', 1): 728,
#  ('wkli', 1): 57,
#  ('comp', 1): 41,
#  ('fa', 1): 14,
#  ('cup', 1): 14,
#  ('tkt', 1): 11,
#  ('21st', 1): 7,
#  ('2005', 1): 12,
#  ('87121', 1): 12,
#  ('questionstd', 1): 7,
#  ('ratetc', 1): 7,
#  ('08452810075over18', 1): 7,
#  ('annonc', 1): 3,
#  ('year', 1): 54,
#  ('07046744435', 1): 3,
#  ('arrang', 1): 8,
#  ('å1000', 1): 138,
#  ('cash', 1): 235,
#  ('å2000', 1): 124,
#  ('yr', 1): 63,
#  ('repres', 1): 42,
#  ('08714712394', 1): 3,
#  ('10am7pm', 1): 17,
#  ('88800', 1): 3,
#  ('89034', 1): 3,
#  ('premium', 1): 4,
#  ('08718711108', 1): 3,
#  ('r', 1): 91,
#  ('subscrib', 1): 40,
#  ('textcomp', 1): 9,
#  ('wk', 1): 83,
#  ('question', 1): 49,
#  ('follow', 1): 48,
#  ('subsequ', 1): 9,
#  ('charged150pmsg2', 1): 9,
#  ('84128custcar', 1): 9,
#  ('08712405020', 1): 23,
#  ('want', 1): 120,
#  ('3510i', 1): 24,
#  ('deliveredtomorrow', 1): 17,
#  ('300', 1): 26,
#  ('minut', 1): 56,
#  ('100', 1): 61,
#  ('sppok', 1): 5,
#  ('halloween', 1): 13,
#  ('logop', 1): 13,
#  ('plu', 1): 29,
#  ('eeri', 1): 19,
#  ('spook', 1): 21,
#  ('messagethank', 1): 2,
#  ('use', 1): 46,
#  ('subscript', 1): 18,
#  ('150pmsgrcvd', 1): 2,
#  ('skip', 1): 2,
#  ('customercar', 1): 2,
#  ('08718726270', 1): 6,
#  ('suppli', 1): 8,
#  ('cd', 1): 61,
#  ('store', 1): 32,
#  ('choic', 1): 7,
#  ('enter', 1): 56,
#  ('å100', 1): 98,
#  ('music', 1): 87,
#  ('87066', 1): 61,
#  ('tsc', 1): 65,
#  ('wwwldewcomsubs161win150ppmx3', 1): 5,
#  ('09058094565', 1): 12,
#  ('land', 1): 48,
#  ('12hr', 1): 52,
#  ('86888', 1): 13,
#  ('3', 1): 96,
#  ('hour', 1): 31,
#  ('talk', 1): 29,
#  ('time', 1): 76,
#  ('subscribe6gbpmnth', 1): 13,
#  ('inc', 1): 33,
#  ('3hr', 1): 13,
#  ('stoptxtstop', 1): 13,
#  ('wwwgambtv', 1): 10,
#  ('10', 1): 22,
#  ('mth', 1): 14,
#  ('cameravideo', 1): 8,
#  ('keep', 1): 18,
#  ('extra', 1): 29,
#  ('minstext', 1): 3,
#  ('freemsgfeelin', 1): 4,
#  ('kinda', 1): 4,
#  ('lnli', 1): 4,
#  ('hope', 1): 13,
#  ('like', 1): 52,
#  ('compani', 1): 10,
#  ('jst', 1): 4,
#  ('got', 1): 32,
#  ('cam', 1): 5,
#  ('mobi', 1): 9,
#  ('wan', 1): 52,
#  ('na', 1): 40,
#  ('pictxt', 1): 4,
#  ('date', 1): 92,
#  ('82242', 1): 9,
#  ('msg150p', 1): 5,
#  ('2rcv', 1): 5,
#  ('hlp', 1): 5,
#  ('08712317606', 1): 5,
#  ('alert', 1): 18,
#  ('left', 1): 2,
#  ('07008009200', 1): 2,
#  ('activ', 1): 33,
#  ('condit', 1): 26,
#  ('visit', 1): 32,
#  ('www07781482378com', 1): 10,
#  ('proze', 1): 6,
#  ('norcorp', 1): 6,
#  ('ltdå150mtmsgrcvd18', 1): 6,
#  ('ou', 1): 5,
#  ('ukp2000', 1): 4,
#  ('09061790125', 1): 4,
#  ('landlin', 1): 121,
#  ('3030', 1): 19,
#  ('ring', 1): 11,
#  ('poli', 1): 90,
#  ('87131', 1): 19,
#  ('0870737910216yr', 1): 5,
#  ('å150wk', 1): 5,
#  ('rip', 1): 3,
#  ('wwwclubmobycom', 1): 3,
#  ('08717509990', 1): 3,
#  ('polytruepixringtonesgam', 1): 3,
#  ('six', 1): 10,
#  ('download', 1): 26,
#  ('gent', 1): 7,
#  ('09064012160', 1): 7,
#  ('k52', 1): 11,
#  ('await', 1): 119,
#  ('08718723815', 1): 6,
#  ('mani', 1): 10,
#  ('virgin', 1): 7,
#  ('readi', 1): 21,
#  ('4fil', 1): 8,
#  ('sexual', 1): 4,
#  ('need', 1): 35,
#  ('cute', 1): 4,
#  ('69911å150p', 1): 4,
#  ('yesterday', 1): 16,
#  ('still', 1): 36,
#  ('09061702893', 1): 11,
#  ('bear', 1): 5,
#  ('pic', 1): 102,
#  ('nick', 1): 1,
#  ('tom', 1): 1,
#  ('pete', 1): 1,
#  ('dick', 1): 1,
#  ('fact', 1): 1,
#  ('type', 1): 1,
#  ('gay', 1): 17,
#  ('photo', 1): 6,
#  ('upload', 1): 4,
#  ('08718730666', 1): 4,
#  ('10pmin', 1): 34,
#  ('08712460324', 1): 26,
#  ('eastend', 1): 12,
#  ('tv', 1): 29,
#  ('flower', 1): 13,
#  ('dot', 1): 12,
#  ('compar', 1): 12,
#  ('violet', 1): 12,
#  ('e', 1): 28,
#  ('tulip', 1): 12,
#  ('f', 1): 33,
#  ('lili', 1): 12,
#  ('84025', 1): 14,
#  ('wkent150p16', 1): 12,
#  ('hmv', 1): 36,
#  ('bonu', 1): 109,
#  ('genuin', 1): 12,
#  ('answer', 1): 35,
#  ('easi', 1): 53,
#  ('infowww100percentrealcom', 1): 12,
#  ('day', 1): 119,
#  ('euro2004', 1): 17,
#  ('kickoff', 1): 9,
#  ('kept', 1): 13,
#  ('inform', 1): 48,
#  ('result', 1): 13,
#  ('daili', 1): 15,
#  ('euro', 1): 14,
#  ('83222', 1): 13,
#  ('vote', 1): 6,
#  ('sing', 1): 12,
#  ('along', 1): 6,
#  ('star', 1): 13,
#  ('karaok', 1): 6,
#  ('link', 1): 22,
#  ('caller', 1): 67,
#  ('09058095201', 1): 5,
#  ('iscom', 1): 15,
#  ('either', 1): 50,
#  ('gift', 1): 81,
#  ('tnc', 1): 41,
#  ('wwwldewcom1win150ppmx3age16subscript', 1): 7,
#  ('gr8', 1): 20,
#  ('str8', 1): 5,
#  ('classic', 1): 5,
#  ('hit', 1): 17,
#  ('nokia150p', 1): 5,
#  ('poly200p', 1): 5,
#  ('ever', 1): 7,
#  ('thought', 1): 1,
#  ('good', 1): 60,
#  ('life', 1): 10,
#  ('perfect', 1): 1,
#  ('partner', 1): 13,
#  ('back', 1): 89,
#  ('commun', 1): 4,
#  ('100psm', 1): 1,
#  ('07xxxxxxxxx', 1): 18,
#  ('020603', 1): 27,
#  ('reach', 1): 28,
#  ('09066362231', 1): 22,
#  ('asap', 1): 30,
#  ('box97n7qp', 1): 20,
#  ('lord', 1): 5,
#  ('ringsreturn', 1): 5,
#  ('king', 1): 11,
#  ('nowrepli', 1): 5,
#  ('lotr', 1): 10,
#  ('june', 1): 5,
#  ('soundtrack', 1): 5,
#  ('stdtxtrate', 1): 5,
#  ('100603', 1): 1,
#  ('09066368753', 1): 1,
#  ('97n7qp', 1): 1,
#  ('congratul', 1): 63,
#  ('friend', 1): 77,
#  ('08712103738', 1): 9,
#  ('10p', 1): 63,
#  ('btnationalr', 1): 34,
#  ('sipix', 1): 17,
#  ('digit', 1): 30,
#  ('09061221066', 1): 10,
#  ('fromm', 1): 10,
#  ('within', 1): 22,
#  ('28', 1): 12,
#  ('dear', 1): 65,
#  ('0776xxxxxxx', 1): 7,
#  ('uve', 1): 25,
#  ('invit', 1): 46,
#  ('xchat', 1): 19,
#  ('150pmsgrcvdhgsuite3422landsroww1j6hl', 1): 17,
#  ('ldn', 1): 41,
#  ('18yr', 1): 9,
#  ('newest', 1): 13,
#  ('åòharri', 1): 5,
#  ('potter', 1): 11,
#  ('phoenix', 1): 11,
#  ('book', 1): 35,
#  ('5', 1): 39,
#  ('harri', 1): 11,
#  ('first', 1): 23,
#  ('among', 1): 11,
#  ('reader', 1): 11,
#  ('rock', 1): 6,
#  ('chik', 1): 6,
#  ('filthi', 1): 11,
#  ('film', 1): 21,
#  ('xxx', 1): 51,
#  ('rpli', 1): 15,
#  ('filth', 1): 6,
#  ('69669', 1): 11,
#  ('saristar', 1): 6,
#  ('e14', 1): 6,
#  ('9yt', 1): 6,
#  ('08701752560', 1): 6,
#  ('450p', 1): 6,
#  ('stop2', 1): 6,
#  ('cancel', 1): 16,
#  ('wont', 1): 12,
#  ('believ', 1): 7,
#  ('true', 1): 13,
#  ('incred', 1): 7,
#  ('g', 1): 14,
#  ('learn', 1): 7,
#  ('truli', 1): 12,
#  ('amaz', 1): 13,
#  ('thing', 1): 7,
#  ('blow', 1): 7,
#  ('mind', 1): 12,
#  ('o2fwd', 1): 7,
#  ('18ptxt', 1): 7,
#  ('set', 1): 19,
#  ('meet', 1): 31,
#  ('09096102316', 1): 7,
#  ('cum', 1): 24,
#  ('2moro', 1): 7,
#  ('jane', 1): 7,
#  ('xx', 1): 13,
#  ('callså1minmoremobsemspobox45po139wa', 1): 9,
#  ('09066350750', 1): 10,
#  ('complimentari', 1): 46,
#  ('ibiza', 1): 16,
#  ('10000', 1): 10,
#  ('sae', 1): 80,
#  ('434', 1): 12,
#  ('sk3', 1): 12,
#  ('8wp', 1): 12,
#  ('150', 1): 43,
#  ('ppm', 1): 15,
#  ('polyphon', 1): 18,
#  ('pt2', 1): 9,
#  ('87575', 1): 16,
#  ('txtin', 1): 19,
#  ('150ptone', 1): 26,
#  ('hl', 1): 26,
#  ('4info', 1): 19,
#  ('07734396839', 1): 11,
#  ('ibh', 1): 11,
#  ('nokia6600', 1): 11,
#  ('å10', 1): 18,
#  ('txtauctiontxt', 1): 11,
#  ('wordstart', 1): 11,
#  ('no81151', 1): 11,
#  ('now4t', 1): 11,
#  ('great', 1): 46,
#  ('best', 1): 39,
#  ('tariff', 1): 21,
#  ('2stoptxt', 1): 15,
#  ('luck', 1): 33,
#  ('place', 1): 24,
#  ('28th', 1): 9,
#  ('feb', 1): 9,
#  ('06', 1): 9,
#  ('remov', 1): 32,
#  ('87239', 1): 25,
#  ('08708034412', 1): 17,
#  ('well', 1): 38,
#  ('done', 1): 14,
#  ('costa', 1): 25,
#  ('del', 1): 32,
#  ('sol', 1): 25,
#  ('å5000', 1): 77,
#  ('09050090044', 1): 23,
#  ('toclaim', 1): 23,
#  ('pobox334', 1): 23,
#  ('stockport', 1): 23,
#  ('sk38xh', 1): 30,
#  ('costå150pm', 1): 23,
#  ('max10min', 1): 23,
#  ('sm', 1): 102,
#  ('inclus', 1): 22,
#  ('credit', 1): 75,
#  ('goto', 1): 25,
#  ('wwwcomuknet', 1): 21,
#  ('login', 1): 21,
#  ('3qxj9', 1): 18,
#  ('08702840625comuk', 1): 15,
#  ('220cm2', 1): 15,
#  ('9ae', 1): 18,
#  ('20', 1): 8,
#  ('opt', 1): 46,
#  ('08452810071', 1): 3,
#  ('09066362220', 1): 4,
#  ('09061221061', 1): 7,
#  ('28day', 1): 7,
#  ('box177', 1): 7,
#  ('m221bp', 1): 7,
#  ('2yr', 1): 7,
#  ('warranti', 1): 7,
#  ('p', 1): 13,
#  ('på399', 1): 7,
#  ('sonyericsson', 1): 21,
#  ('dvd', 1): 25,
#  ('call2optout4qf2', 1): 6,
#  ('å250', 1): 51,
#  ('84128', 1): 11,
#  ('wwwtextcompcom', 1): 9,
#  ('cust', 1): 16,
#  ('care', 1): 32,
#  ('tddnewsletteremc1couk', 1): 7,
#  ('game', 1): 100,
#  ('thedailydraw', 1): 7,
#  ('helen', 1): 7,
#  ('dozen', 1): 7,
#  ('prizeswith', 1): 7,
#  ('vodafon', 1): 24,
#  ('4882', 1): 9,
#  ('match', 1): 65,
#  ('09064019014', 1): 9,
#  ('09090900040', 1): 5,
#  ('listen', 1): 12,
#  ('extrem', 1): 5,
#  ('dirti', 1): 5,
#  ('offic', 1): 5,
#  ('right', 1): 14,
#  ('total', 1): 9,
#  ('privaci', 1): 5,
#  ('one', 1): 43,
#  ('know', 1): 79,
#  ('sic', 1): 5,
#  ('60p', 1): 5,
#  ('247mp', 1): 5,
#  ('0870753331018', 1): 5,
#  ('08714712412', 1): 5,
#  ('heard', 1): 14,
#  ('u4', 1): 14,
#  ('rude', 1): 12,
#  ('privat', 1): 75,
#  ('01223585334', 1): 12,
#  ('2c', 1): 12,
#  ('gettin', 1): 12,
#  ('shag', 1): 14,
#  ('pix', 1): 13,
#  ('8552', 1): 24,
#  ('2end', 1): 12,
#  ('sam', 1): 16,
#  ('zed', 1): 29,
#  ('uniqu', 1): 13,
#  ('user', 1): 42,
#  ('id', 1): 16,
#  ('1172', 1): 8,
#  ('check', 1): 12,
#  ('choos', 1): 30,
#  ('babe', 1): 23,
#  ('smsshsexnetun', 1): 4,
#  ('fgkslpopw', 1): 4,
#  ('fgkslpo', 1): 4,
#  ('competit', 1): 12,
#  ('80086', 1): 4,
#  ('wwwtxttowincouk', 1): 4,
#  ('import', 1): 45,
#  ('02', 1): 5,
#  ('lucki', 1): 37,
#  ('find', 1): 82,
#  ('log', 1): 37,
#  ('onto', 1): 37,
#  ('httpwwwurawinnercom', 1): 32,
#  ('fantast', 1): 35,
#  ('surpris', 1): 28,
#  ('youv', 1): 9,
#  ('your', 1): 7,
#  ('winner', 1): 64,
#  ('august', 1): 7,
#  ('09066660100', 1): 2,
#  ('2309', 1): 2,
#  ('goal', 1): 12,
#  ('arsen', 1): 16,
#  ('henri', 1): 10,
#  ('7', 1): 8,
#  ('liverpool', 1): 9,
#  ('score', 1): 15,
#  ('simpl', 1): 5,
#  ('shot', 1): 5,
#  ('6', 1): 17,
#  ('yard', 1): 5,
#  ('pass', 1): 21,
#  ('bergkamp', 1): 5,
#  ('give', 1): 28,
#  ('margin', 1): 5,
#  ('78', 1): 5,
#  ('22', 1): 10,
#  ('146tf150p', 1): 6,
#  ('guess', 1): 20,
#  ('somebodi', 1): 10,
#  ('secretli', 1): 10,
#  ('fanci', 1): 34,
#  ('us', 1): 23,
#  ('09065394514', 1): 5,
#  ('datebox1282essexcm61xn', 1): 10,
#  ('150pmin', 1): 15,
#  ('congrat', 1): 37,
#  ('cinema', 1): 7,
#  ('09061209465', 1): 7,
#  ('suprman', 1): 7,
#  ('matrix3', 1): 7,
#  ('starwars3', 1): 7,
#  ('etc', 1): 15,
#  ('bx420ip45w', 1): 7,
#  ('150pm', 1): 17,
#  ('start', 1): 55,
#  ('wwwidewcom', 1): 5,
#  ('skillgam', 1): 5,
#  ('1winaweek', 1): 5,
#  ('age16', 1): 19,
#  ('150ppermesssubscript', 1): 5,
#  ('08712400200', 1): 5,
#  ('simpli', 1): 11,
#  ('password', 1): 11,
#  ('mix', 1): 14,
#  ('85069', 1): 7,
#  ('verifi', 1): 13,
#  ('usher', 1): 7,
#  ('britney', 1): 7,
#  ('fml', 1): 7,
#  ('explicit', 1): 4,
#  ('sex', 1): 31,
#  ('30', 1): 8,
#  ('sec', 1): 4,
#  ('02073162414', 1): 4,
#  ('20pmin', 1): 4,
#  ('gsex', 1): 2,
#  ('2667', 1): 2,
#  ('wc1n', 1): 2,
#  ('3xx', 1): 2,
#  ('themobhit', 1): 1,
#  ('pink', 1): 1,
#  ('panther', 1): 1,
#  ('sugabab', 1): 1,
#  ('crazi', 1): 19,
#  ('zebra', 1): 1,
#  ('anim', 1): 1,
#  ('badass', 1): 1,
#  ('hoodi', 1): 1,
#  ('wallpaperal', 1): 1,
#  ('09066364311', 1): 14,
#  ('valu', 1): 62,
#  ('realiz', 1): 6,
#  ('40', 1): 8,
#  ('thousand', 1): 6,
#  ('old', 1): 9,
#  ('ladi', 1): 11,
#  ('run', 1): 6,
#  ('around', 1): 15,
#  ('tattoo', 1): 6,
#  ('footbal', 1): 10,
#  ('sky', 1): 20,
#  ('gamestar', 1): 10,
#  ('å250k', 1): 10,
#  ('dream', 1): 13,
#  ('saturday', 1): 22,
#  ('regist', 1): 26,
#  ('nowski', 1): 10,
#  ('88088', 1): 10,
#  ('save', 1): 11,
#  ('ås', 1): 5,
#  ('textsweekend', 1): 5,
#  ('callback', 1): 9,
#  ('orno', 1): 5,
#  ('secret', 1): 39,
#  ('admir', 1): 39,
#  ('look', 1): 50,
#  ('ufind', 1): 33,
#  ('rreveal', 1): 33,
#  ('specialcal', 1): 33,
#  ('09058094599', 1): 10,
#  ('matthew', 1): 7,
#  ('09063440451', 1): 7,
#  ('4lux', 1): 7,
#  ('tenerif', 1): 32,
#  ('ppm150', 1): 7,
#  ('box334', 1): 7,
#  ('next', 1): 68,
#  ('picsfree1', 1): 12,
#  ('sent', 1): 47,
#  ('vid', 1): 6,
#  ('enough', 1): 11,
#  ('2day', 1): 13,
#  ('keyword', 1): 6,
#  ('unclaim', 1): 2,
#  ('09066368327', 1): 2,
#  ('closingdate040902', 1): 2,
#  ('claimcod', 1): 2,
#  ('m39m51', 1): 2,
#  ('å150pmmorefrommobile2bremovedmobypobox734ls27yf', 1): 2,
#  ('08708800282', 1): 4,
#  ('access', 1): 26,
#  ('08709501522', 1): 3,
#  ('detail', 1): 31,
#  ('139', 1): 3,
#  ('la3', 1): 3,
#  ('2wu', 1): 3,
#  ('å150week', 1): 3,
#  ('datingi', 1): 4,
#  ('two', 1): 4,
#  ('sport', 1): 25,
#  ('radio', 1): 4,
#  ('connect', 1): 18,
#  ('coincid', 1): 4,
#  ('five', 1): 14,
#  ('08000776320', 1): 10,
#  ('tomorrow', 1): 34,
#  ('bloomberg', 1): 4,
#  ('center', 1): 4,
#  ('447797706009', 1): 4,
#  ('futur', 1): 10,
#  ('httpcareer', 1): 4,
#  ('bloombergcom', 1): 4,
#  ('å12', 1): 4,
#  ('å800', 1): 22,
#  ('09050000460', 1): 3,
#  ('j89', 1): 3,
#  ('box245c2150pm', 1): 3,
#  ('09058094594', 1): 5,
#  ('85233', 1): 3,
#  ('freeringtonerepli', 1): 3,
#  ('real', 1): 51,
#  ('4mth', 1): 13,
#  ('half', 1): 54,
#  ('rental', 1): 48,
#  ('mobilesdirect', 1): 13,
#  ('08000938767', 1): 13,
#  ('or2stoptxt', 1): 13,
#  ('bore', 1): 18,
#  ('speed', 1): 4,
#  ('speedchat', 1): 8,
#  ('80155', 1): 4,
#  ('em', 1): 4,
#  ('swap', 1): 4,
#  ('chatter', 1): 4,
#  ('chat80155', 1): 4,
#  ('pobox36504w45wq', 1): 16,
#  ('rcd', 1): 4,
#  ('advis', 1): 17,
#  ('review', 1): 20,
#  ('å1500', 1): 28,
#  ('09066364589', 1): 13,
#  ('hardcor', 1): 10,
#  ('porn', 1): 17,
#  ('direct', 1): 41,
#  ('69200', 1): 4,
#  ('24', 1): 9,
#  ('hr', 1): 4,
#  ('chrgd50p', 1): 4,
#  ('2exit', 1): 4,
#  ('gnarl', 1): 4,
#  ('barkley', 1): 4,
#  ('textpod', 1): 7,
#  ('pod', 1): 13,
#  ('wwwtextpodnet', 1): 7,
#  ('custcar', 1): 26,
#  ('wwwldewcom', 1): 14,
#  ('skillgame1winaweek', 1): 7,
#  ('age16150ppermesssubscript', 1): 7,
#  ('4u', 1): 12,
#  ('titl', 1): 16,
#  ('dracula', 1): 6,
#  ('ghost', 1): 6,
#  ('addamsfa', 1): 6,
#  ('munster', 1): 6,
#  ('exorcist', 1): 6,
#  ('twilight', 1): 6,
#  ('150p', 1): 74,
#  ('banneduk', 1): 3,
#  ('89555', 1): 8,
#  ('see', 1): 93,
#  ('textoper', 1): 8,
#  ('g696ga', 1): 5,
#  ('08717898035', 1): 17,
#  ('unsub', 1): 18,
#  ('x', 1): 37,
#  ('call09050000327', 1): 8,
#  ('rstm', 1): 10,
#  ('sw7', 1): 10,
#  ('3ss', 1): 10,
#  ('b', 1): 46,
#  ('floppi', 1): 3,
#  ('snappi', 1): 3,
#  ('happi', 1): 3,
#  ('ya', 1): 5,
#  ('4goten', 1): 5,
#  ('bout', 1): 5,
#  ('scammer', 1): 5,
#  ('smartthough', 1): 5,
#  ('regular', 1): 5,
#  ('respond', 1): 14,
#  ('prem', 1): 5,
#  ('msgsubscript', 1): 5,
#  ...}

# %% [markdown]
# ## Training the Naive Bayes Model
#
# Now we are in the training phase of the Naive Bayes algorithm. In this cell, take a look at the ways to calculate the log likelihood and log prior values as these are important for testing in the next few cells.
#
# Also calculate the frequency of occurrence of words where the output is spam. In the same way, calculate the word frequency count using the above functions in order to compute the log likelihood.
#
# Return the logprior and loglikelihood output by the model from this function.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of messages
        train_y: a list of labels correponding to the messages (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0


    # calculate V, the number of unique words in the vocabulary
    # vocab = set(freqs.keys([0]))
    # vocab = [ele for key in freqs.keys() for ele in key[0]]
    # for pair in freqs.keys():
        #vocab = list(set(pair[0]))
        
        
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)
    


    # calculate num_pos and num_neg - the total number of positive and negative words for all documents
    num_pos = num_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1]>0:

            # Increment the number of positive words by the count for this (word, label) pair
            num_pos += freqs[pair] 

        # else, the label is negative
        else:

            # increment the number of negative words by the count for this (word,label) pair
            num_neg += freqs[pair]
    # Calculate num_doc, the number of documents
    num_doc = len(X_train)

    # Calculate D_pos, the number of positive documents 
    pos_num_docs=0
    for label in y_train:
        if label==1 :
            pos_num_docs += 1

    # Calculate D_neg, the number of negative documents 
    neg_doc = filter(lambda x: x <= 0, train_y)
    list1 = list(neg_doc)
    neg_num_docs = len(list1)

    # Calculate logprior
    logprior = pos_num_docs - neg_num_docs

    # For each word in the vocabulary...
    for word in vocab:
        # get the spam and ham frequency of the word
        freq_pos = find_occurrence(freqs,word,1)
        freq_neg = find_occurrence(freqs,word,0)

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos + 1)/(num_pos + V)
        p_w_neg = (freq_neg + 1)/(num_neg + V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos) - np.log(p_w_neg)

    return logprior, loglikelihood

# %%
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
logprior, loglikelihood = train_naive_bayes(freqs, X_train, y_train)
print(logprior)
print(len(loglikelihood))
# Out:
# 0
# 6719

# %% [markdown]
# ## Implementing Naive Bayes Predict Function
#
# It is now time to make our prediction as to whether a given message is spam or ham respectively.
#
# After adding the log likelihood values, ensure that the output is 1 (spam) if the sum of the log likelihood value is greater than 0 and 0 (ham) if the sum of the log likelihood is less than or equal to 0.

# %%
# TASK 4 CELL

def naive_bayes_predict(message, logprior, loglikelihood):
    '''
    Params:
        message: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Return:
        total_prob: the sum of all the loglikelihoods of each word in the message (if found in the dictionary) + logprior (a number)

    '''
    
     # process the message to get a list of words
    word_l = clean_message(message)

    # initialize probability to zero
    total_prob = 0

    # add the logprior
    total_prob += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood :
            # add the log likelihood of that word to the probability
            total_prob = total_prob + loglikelihood[word]
    
    if total_prob > 0:
        
        total_prob = 1
    else:
        
        total_prob = 0
        
    return total_prob

# %%
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Experiment with your own message.
my_message = 'She smiled.'
p = naive_bayes_predict(my_message, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 0

# %% [markdown]
# ## Implementing Naive Bayes Test function
#
# In this function, implement the previous functions such as naive_bayes_predict to get the predictions for the test set.
#
# In addition to this, the function should return the total number of messages that it correctly classified as 'spam' or 'ham'.

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of messages
        test_y: the corresponding labels for the list of messages
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of messages classified correctly)/(total # of message)
    """
    accuracy = 0  

    
    y_hats = []
    for message in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(message, logprior, loglikelihood)>0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    abs_diff = np.absolute(y_hats-test_y)
    error =  np.mean(abs_diff)

    accuracy = 1 - error


    return accuracy

# %%
# For grading purpose only
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Run this cell to test your function
for message in ['get an offer', 'get the latest movie review', 'order iphone', 'I am on a meeting']:
    # print( '%s -> %f' % (message, naive_bayes_predict(message, logprior, loglikelihood)))
    p = naive_bayes_predict(message, logprior, loglikelihood)
#     print(f'{message} -> {p:.2f} ({p_category})')
    print(f'{message} -> {p:.2f}')
# Out:
# get an offer -> 1.00
# get the latest movie review -> 1.00
# order iphone -> 1.00
# I am on a meeting -> 0.00

# %%
# Feel free to check the sentiment of your own message below
my_message = 'get an offer of iphone 13 and grab your order'
naive_bayes_predict(my_message, logprior, loglikelihood)
# Out:
# 1
